# %% [markdown]
# # 反爬：登入授權模擬
#
# * 了解「登入權限機制」的反爬蟲機制
# * 「登入權限機制」反爬蟲的因應策略

# %% [markdown]
# ## 未授權前存取

# %%
import requests
from bs4 import BeautifulSoup

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html', verify = False)
soup = BeautifulSoup(res.text, 'html.parser')
print(soup.text)
# Out:
# C:\Users\qwerz\Miniconda3\envs\PCM\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# C:\Users\qwerz\Miniconda3\envs\PCM\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 本網站已依網站內容分級規定處理
# 警告︰您即將進入之看板內容需滿十八歲方可瀏覽。
# 若您尚未年滿十八歲，請點選離開。若您已滿十八歲，亦不可將本區之內容派發、傳閱、出售、出租、交給或借予年齡未滿18歲的人士瀏覽，或將本網站內容向該人士出示、播放或放映。
#
#
#
#
#
#
# 我同意，我已年滿十八歲進入
#
#
# 未滿十八歲或不同意本條款離開
#
#
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');

# %% [markdown]
# ## 模仿授權機制

# %% [markdown]
# ### 方法一：先送登入，再送請求

# %%
rs = requests.session()
payload={
    'from':'/bbs/Gossiping/index.html',
    'yes': 'yes'
}
res = rs.post('https://www.ptt.cc/ask/over18',verify = False, data = payload)
res = rs.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False)
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# C:\Users\qwerz\Miniconda3\envs\PCM\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# C:\Users\qwerz\Miniconda3\envs\PCM\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# C:\Users\qwerz\Miniconda3\envs\PCM\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 2
#
# [問卦] 整天都沒出門有必要洗澡嗎？
#
#
# Timekeeper
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Timekeeper 的文章
#
#
#  1/31
#
#
#
#
# 1
#
# Re: [新聞] 武漢肺炎確診來到第10例！　「漏網輕症」
#
#
# doomdied
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 doomdied 的文章
#
#
#  1/31
#
#
#
#
# 4
#
# Re: [問卦] 版上1450蟑螂是不是變多了
#
#
# NARUTO
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 NARUTO 的文章
#
#
#  1/31
#
#
#
#
#
#
#
# 				(本文已被刪除) [Fw200]
#
#
#
# -
#
#
#  1/31
#
#
#
#
# 7
#
# [問卦] 買肉去大賣場划算嗎
#
#
# mayingnine
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 mayingnine 的文章
#
#
#  1/31
#
#
#
#
#
#
# [問卦] 血型不同會不會影響病毒防禦力
#
#
# gentleman45
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 gentleman45 的文章
#
#
#  1/31
#
#
#
#
# 10
#
# [新聞] 扯！移民署國境事務大隊 發給隊員的口罩
#
#
# LinuxKernel
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 LinuxKernel 的文章
#
#
#  1/31
#
#
#
#
#
#
# [問卦] 若明宣布衛生紙將調漲,大媽還搶排口罩嗎?
#
#
# common5566
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 common5566 的文章
#
#
#  1/31
#
#
#
#
#
#
# [新聞] 新西蘭航空將減少奧克蘭至上海航班
#
#
# andrewkuo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 andrewkuo 的文章
#
#
#  1/31
#
#
#
#
# 3
#
# [問卦] 口罩終究還是會短缺嗎？
#
#
# torrestam
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 torrestam 的文章
#
#
#  1/31
#
#
#
#
#
#
# Re: [新聞] 台灣GDP登亞洲四小龍之首　為何年終仍減
#
#
# onetwogo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 onetwogo 的文章
#
#
#  1/31
#
#
#
#
# 26
#
# Re: [問卦] 哆啦A夢的翻譯蒟蒻翻譯過多少種語言了?
#
#
# ffaarr
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ffaarr 的文章
#
#
#  1/31
#
#
#
#
# 1
#
# Re: [問卦] 哈佛的范瑋琪不知道甚麼是全球化主義...
#
#
# abasqoo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 abasqoo 的文章
#
#
#  1/31
#
#
#
#
# 5
#
# [爆卦] 武漢肺炎韓國第11例 境內三次傳染途徑
#
#
# suzhou
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 suzhou 的文章
#
#
#  1/31
#
#
#
#
# 2
#
# [問卦] 學校還不停止寒輔在想什麼？
#
#
# eereer12325
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 eereer12325 的文章
#
#
#  1/31
#
#
#
#
#
#
# Re: [問卦] 為什麼台灣不停飛中國航班?
#
#
# stp60779
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 stp60779 的文章
#
#
#  1/31
#
#
#
#
#
#
# [爆卦] 俄羅斯出現兩個武漢肺炎確診病例
#
#
# powerdavid
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 powerdavid 的文章
#
#
#  1/31
#
#
#
#
#
# 61
#
# [公告] 請勿散佈錯假訊息
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  1/22
# M
#
#
#
# 6
#
# Fw: [徵求] 行車紀錄器 1/19 民生社區 下午五點半左
#
#
# maxjoiny
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 maxjoiny 的文章
#
#
#  1/26
#
#
#
#
# 21
#
# [公告] 因應武漢肺炎即時官方訊息暨討論區
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  1/25
# M
#
#
#
# 4
#
# [公告] 八卦板主徵選報名2/1開始
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  1/31
# M
#
#
#
# 3
#
# [公告] 關於板上疫情相關問卦&八卦板板規
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  1/31
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');

# %% [markdown]
# ### 方法二：在請求中帶入 cookie

# %%
res = requests.get('https://www.ptt.cc/bbs/Gossiping/index.html',verify = False, cookies={'over18': '1'})
soup = BeautifulSoup(res.text,'html.parser')
print(soup.text)
# Out:
# C:\Users\qwerz\Miniconda3\envs\PCM\lib\site-packages\urllib3\connectionpool.py:1004: InsecureRequestWarning: Unverified HTTPS request is being made. Adding certificate verification is strongly advised. See: https://urllib3.readthedocs.io/en/latest/advanced-usage.html#ssl-warnings
#   InsecureRequestWarning,
# 看板 Gossiping 文章列表 - 批踢踢實業坊
#
#
#
#
#
#
#
#
#
# 批踢踢實業坊
# ›
# 看板 Gossiping
# 關於我們
# 聯絡資訊
#
#
#
#
#
#
# 看板
# 精華區
#
#
# 最舊
# ‹ 上頁
# 下頁 ›
# 最新
#
#
#
#
#
#
#
#
#
#
# 2
#
# [問卦] 整天都沒出門有必要洗澡嗎？
#
#
# Timekeeper
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Timekeeper 的文章
#
#
#  1/31
#
#
#
#
# 1
#
# Re: [新聞] 武漢肺炎確診來到第10例！　「漏網輕症」
#
#
# doomdied
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 doomdied 的文章
#
#
#  1/31
#
#
#
#
# 4
#
# Re: [問卦] 版上1450蟑螂是不是變多了
#
#
# NARUTO
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 NARUTO 的文章
#
#
#  1/31
#
#
#
#
#
#
#
# 				(本文已被刪除) [Fw200]
#
#
#
# -
#
#
#  1/31
#
#
#
#
# 7
#
# [問卦] 買肉去大賣場划算嗎
#
#
# mayingnine
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 mayingnine 的文章
#
#
#  1/31
#
#
#
#
#
#
# [問卦] 血型不同會不會影響病毒防禦力
#
#
# gentleman45
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 gentleman45 的文章
#
#
#  1/31
#
#
#
#
# 10
#
# [新聞] 扯！移民署國境事務大隊 發給隊員的口罩
#
#
# LinuxKernel
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 LinuxKernel 的文章
#
#
#  1/31
#
#
#
#
#
#
# [問卦] 若明宣布衛生紙將調漲,大媽還搶排口罩嗎?
#
#
# common5566
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 common5566 的文章
#
#
#  1/31
#
#
#
#
#
#
# [新聞] 新西蘭航空將減少奧克蘭至上海航班
#
#
# andrewkuo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 andrewkuo 的文章
#
#
#  1/31
#
#
#
#
# 3
#
# [問卦] 口罩終究還是會短缺嗎？
#
#
# torrestam
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 torrestam 的文章
#
#
#  1/31
#
#
#
#
#
#
# Re: [新聞] 台灣GDP登亞洲四小龍之首　為何年終仍減
#
#
# onetwogo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 onetwogo 的文章
#
#
#  1/31
#
#
#
#
# 27
#
# Re: [問卦] 哆啦A夢的翻譯蒟蒻翻譯過多少種語言了?
#
#
# ffaarr
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 ffaarr 的文章
#
#
#  1/31
#
#
#
#
# 1
#
# Re: [問卦] 哈佛的范瑋琪不知道甚麼是全球化主義...
#
#
# abasqoo
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 abasqoo 的文章
#
#
#  1/31
#
#
#
#
# 5
#
# [爆卦] 武漢肺炎韓國第11例 境內三次傳染途徑
#
#
# suzhou
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 suzhou 的文章
#
#
#  1/31
#
#
#
#
# 2
#
# [問卦] 學校還不停止寒輔在想什麼？
#
#
# eereer12325
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 eereer12325 的文章
#
#
#  1/31
#
#
#
#
#
#
# Re: [問卦] 為什麼台灣不停飛中國航班?
#
#
# stp60779
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 stp60779 的文章
#
#
#  1/31
#
#
#
#
#
#
# [爆卦] 俄羅斯出現兩個武漢肺炎確診病例
#
#
# powerdavid
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 powerdavid 的文章
#
#
#  1/31
#
#
#
#
#
# 61
#
# [公告] 請勿散佈錯假訊息
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  1/22
# M
#
#
#
# 6
#
# Fw: [徵求] 行車紀錄器 1/19 民生社區 下午五點半左
#
#
# maxjoiny
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 maxjoiny 的文章
#
#
#  1/26
#
#
#
#
# 21
#
# [公告] 因應武漢肺炎即時官方訊息暨討論區
#
#
# Bignana
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 Bignana 的文章
#
#
#  1/25
# M
#
#
#
# 4
#
# [公告] 八卦板主徵選報名2/1開始
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  1/31
# M
#
#
#
# 3
#
# [公告] 關於板上疫情相關問卦&八卦板板規
#
#
# arsonlolita
#
# ⋯
#
# 搜尋同標題文章
# 搜尋看板內 arsonlolita 的文章
#
#
#  1/31
# M
#
#
#
# 本網站已依台灣網站內容分級規定處理。此區域為限制級，未滿十八歲者不得瀏覽。
#
#
#   (function(i,s,o,g,r,a,m){i['GoogleAnalyticsObject']=r;i[r]=i[r]||function(){
#   (i[r].q=i[r].q||[]).push(arguments)},i[r].l=1*new Date();a=s.createElement(o),
#   m=s.getElementsByTagName(o)[0];a.async=1;a.src=g;m.parentNode.insertBefore(a,m)
#   })(window,document,'script','https://www.google-analytics.com/analytics.js','ga');
#
#   ga('create', 'UA-32365737-1', {
#     cookieDomain: 'ptt.cc',
#     legacyCookieDomain: 'ptt.cc'
#   });
#   ga('send', 'pageview');

# %% [markdown]
# ## 作業目標
#
# * 找一個需要登入的網站試試看，並說明思考流程
# （如果不知道要用哪個網站的話，可以試試看 https://github.com/new 網址，未登入時會被導向登入頁）
